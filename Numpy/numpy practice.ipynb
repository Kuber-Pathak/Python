# %%
import numpy as np

# %%
a = np.array([1,2,4],dtype= "int16")
print (a)
# Out:
# [1 2 4]

# %%
# get diminsion
a.ndim
# Out:
# 1

# %%
b = np.array([[1,2,3],[4,5,6]])
print(b)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
# get shape
b.shape
# Out:
# (2, 3)

# %%
# get type
a.dtype
# Out:
# dtype('int16')

# %%
#get size
a.itemsize
# Out:
# 2

# %%
#get total bytes
a.nbytes
# Out:
# 6
